# %%
# %%capture
# %pip install qiskit qiskit-aer

# %%
from qiskit.circuit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

simulator = AerSimulator()

# %% [markdown]
# ## Pergunta (1.c)

# %%
# Criar circuito aqui
qc = QuantumCircuit(3)
qc.h(0)
qc.barrier()
qc.cx(0, 1)
qc.cx(0, 2)

qc.measure_all()
qc.draw()
# Out:
#         ┌───┐ ░            ░ ┌─┐
#    q_0: ┤ H ├─░───■────■───░─┤M├──────
#         └───┘ ░ ┌─┴─┐  │   ░ └╥┘┌─┐
#    q_1: ──────░─┤ X ├──┼───░──╫─┤M├───
#               ░ └───┘┌─┴─┐ ░  ║ └╥┘┌─┐
#    q_2: ──────░──────┤ X ├─░──╫──╫─┤M├
#               ░      └───┘ ░  ║  ║ └╥┘
# meas: 3/══════════════════════╩══╩══╩═
#                               0  1  2

# %%
# Simulação
job = simulator.run(qc, nshots=1024)
result = job.result()
counts = result.get_counts()

# %%
# Visualização
plot_histogram(counts)

# %% [markdown]
# ## Pergunta (2.a) -- Circuito XXX

# %%
# Criar circuito aqui
qc = QuantumCircuit(3)

qc.h(0)
qc.cx(0, 1)
qc.cx(0, 2)

qc.barrier()

qc.h(0)
qc.h(1)
qc.h(2)

qc.measure_all()
qc.draw()
# Out:
#         ┌───┐           ░ ┌───┐ ░ ┌─┐
#    q_0: ┤ H ├──■────■───░─┤ H ├─░─┤M├──────
#         └───┘┌─┴─┐  │   ░ ├───┤ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├──┼───░─┤ H ├─░──╫─┤M├───
#              └───┘┌─┴─┐ ░ ├───┤ ░  ║ └╥┘┌─┐
#    q_2: ──────────┤ X ├─░─┤ H ├─░──╫──╫─┤M├
#                   └───┘ ░ └───┘ ░  ║  ║ └╥┘
# meas: 3/═══════════════════════════╩══╩══╩═
#                                    0  1  2

# %%
# Simulação
job = simulator.run(qc, nshots=1024)
result = job.result()
counts = result.get_counts()

# %%
# Visualização
plot_histogram(counts)

# %% [markdown]
# ## Pergunta (2.c) -- Circuito YYX

# %%
# Criar circuito aqui
qc = QuantumCircuit(3)

qc.h(0)
qc.cx(0, 1)
qc.cx(0, 2)

qc.barrier()

qc.h(0)

qc.sdg(1)
qc.h(1)

qc.sdg(2)
qc.h(2)

qc.measure_all()
qc.draw()
# Out:
#         ┌───┐           ░  ┌───┐       ░ ┌─┐
#    q_0: ┤ H ├──■────■───░──┤ H ├───────░─┤M├──────
#         └───┘┌─┴─┐  │   ░ ┌┴───┴┐┌───┐ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├──┼───░─┤ Sdg ├┤ H ├─░──╫─┤M├───
#              └───┘┌─┴─┐ ░ ├─────┤├───┤ ░  ║ └╥┘┌─┐
#    q_2: ──────────┤ X ├─░─┤ Sdg ├┤ H ├─░──╫──╫─┤M├
#                   └───┘ ░ └─────┘└───┘ ░  ║  ║ └╥┘
# meas: 3/══════════════════════════════════╩══╩══╩═
#                                           0  1  2

# %%
# Simulação
job = simulator.run(qc, nshots=1024)
result = job.result()
counts = result.get_counts()

# %%
# Visualização
plot_histogram(counts)

# %% [markdown]
# ## Pergunta (2.c) -- Circuito YXY

# %%
# Criar circuito aqui
qc = QuantumCircuit(3)

qc.h(0)
qc.cx(0, 1)
qc.cx(0, 2)

qc.barrier()

qc.sdg(0)
qc.h(0)

qc.h(1)

qc.sdg(2)
qc.h(2)

qc.measure_all()
qc.draw()
# Out:
#         ┌───┐           ░ ┌─────┐┌───┐ ░ ┌─┐
#    q_0: ┤ H ├──■────■───░─┤ Sdg ├┤ H ├─░─┤M├──────
#         └───┘┌─┴─┐  │   ░ └┬───┬┘└───┘ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├──┼───░──┤ H ├───────░──╫─┤M├───
#              └───┘┌─┴─┐ ░ ┌┴───┴┐┌───┐ ░  ║ └╥┘┌─┐
#    q_2: ──────────┤ X ├─░─┤ Sdg ├┤ H ├─░──╫──╫─┤M├
#                   └───┘ ░ └─────┘└───┘ ░  ║  ║ └╥┘
# meas: 3/══════════════════════════════════╩══╩══╩═
#                                           0  1  2

# %%
# Simulação
job = simulator.run(qc, nshots=1024)
result = job.result()
counts = result.get_counts()

# %%
# Visualização
plot_histogram(counts)

# %% [markdown]
# ## Pergunta (2.c) -- Circuito XYY

# %%
# Criar circuito aqui
qc = QuantumCircuit(3)

qc.h(0)
qc.cx(0, 1)
qc.cx(0, 2)

qc.barrier()

qc.sdg(0)
qc.h(0)

qc.sdg(1)
qc.h(1)

qc.h(2)

qc.measure_all()
qc.draw()
# Out:
#         ┌───┐           ░ ┌─────┐┌───┐ ░ ┌─┐
#    q_0: ┤ H ├──■────■───░─┤ Sdg ├┤ H ├─░─┤M├──────
#         └───┘┌─┴─┐  │   ░ ├─────┤├───┤ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├──┼───░─┤ Sdg ├┤ H ├─░──╫─┤M├───
#              └───┘┌─┴─┐ ░ └┬───┬┘└───┘ ░  ║ └╥┘┌─┐
#    q_2: ──────────┤ X ├─░──┤ H ├───────░──╫──╫─┤M├
#                   └───┘ ░  └───┘       ░  ║  ║ └╥┘
# meas: 3/══════════════════════════════════╩══╩══╩═
#                                           0  1  2

# %%
# Simulação
job = simulator.run(qc, nshots=1024)
result = job.result()
counts = result.get_counts()

# %%
# Visualização
plot_histogram(counts)
